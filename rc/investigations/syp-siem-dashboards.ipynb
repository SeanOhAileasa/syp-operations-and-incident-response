# %% [markdown]
# ***
# < [Home](https://github.com/SeanOhAileasa) | [README](https://github.com/SeanOhAileasa/syp-operations-and-incident-response/blob/main/README.md) >
#
# ## CompTIA Security+ - Course Material 2022
# ###### Topic: ``SIEM Dashboards``
# ***

# %% [markdown]
# Course material for the ``CompTIA Security+`` module of the ``ICT Associate Apprenticeship (Cybersecurity)`` programme.

# %% [markdown]
# <a id="top"></a>
# ***
# ## Table of Contents
# ***

# %% [markdown]
# ### [SIEM Dashboards](#a) <br/><br/>
#
# <hr width=50%;>

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="a"></a>
# ***
# ### SIEM Dashboards
# ***

# %% [markdown]
# Security Information and Event Management - this is usually a device that is logging information from many different resources on the network, and consolidating all of those logs back to one single reporting tool.
#
# This allows us to perform analysis of the data to create security alerts and real time information about what’s happening on the network right now - since we have collected all of this log information, we’re aggregating it into one place, and creating a long term storage so that we can create some extensive reports over a long period of time.
#
# There’s also the ability to correlate different types of data together. We’re bringing together data from firewalls, servers, switches, routers, and other devices on the network - this allows us to correlate data together that normally would be completely separate and of course, if we have some type of security event, we can go back through these logs to determine what happened during that time frame, and what other details can we gather about this specific security issue.

# %% [markdown]
# A SIEM can gather information from many different devices - can of course gather log files from operating systems like Windows or Linux, and have that information sent into the central SIEM database.
#
# There’s also log files that are in our switches, our routers, our firewalls, and other devices and of course, those log files can also be parsed and stored in the SIEM database.
#
# Might also use third-party sensors, which follow standards such as NetFlow, that can provide information about traffic flows across our network.
#
# If you can imagine consolidating all of this information from so many different devices into a single database, and then trying to read through the database to find information that we might be able to use, it’s almost overwhelming, so it’s important to use a SIEM that is able to parse the data, and perhaps put the information into different categories.
#
# Perhaps some of these log entries can be categorized as informational - others might have a warning category and others could be categorized as urgent.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Because we’re able to capture this information over a very long period of time, we can start to see trends in the way that the data is changing. We can see spikes whenever a particular security event occurs, or we might be able to tell that a particular network is more or less utilized than normal.
#
# The SIEM also has intelligence that can parse this data, look through the information for details, and proactively provide you with alarming and alerting - could then drill down into the raw data that’s inside the SIEM to be able to create reports and view other details about that event.
#
# Ca n begin correlating these very different data types into a standard set of information, for example, you may be able to see the relationships between source and destination IP addresses, users, source type, and other information that you could gather from the log files.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Connected to SIEM that has 339,000 events inside of the database that go back five years - latest event was two days ago and we can begin searching for information inside of the SIEM:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Performing a search of the word ``fail`` and the word ``password`` and it’s going to search through that database and show all of these log entries that match for ``fail`` and ``password``.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Able to determine that it was Microsoft authentication - see server names and other information inside of it and there’s additional details that you could drill down into if you would like to.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# There’s also information along the left side of the screen that tells me information about, perhaps, what the source type was for these particular records:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It will summarize or create an incident report that shows that 2,400 of these were Windows authentication instances but there were some of Linux devices that had this particular entry, a database audit and a secure file service:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# If we click ``linux_secure``, it will add that to our list and now we’re looking at Linux-specific events where there was a failed password:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Then we can find more information about each one of those events, and what was associated with that particular log file:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# It will be interesting to see what devices had this particular authentication failure - going to choose an option on the left side for the destination (``dest``).
#
# Can see there are eight destinations listed, and 57% of these events were to the ``corpfilesvr``, so now we know exactly which service is having the most number of events, or perhaps the most number of brute force attacks, all because we were able to search very quickly through the SIEM database.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) >
# <a id="references"></a>
# ***
# ## References
# ***

# %% [markdown]
# J. "Professor" Messer, "CompTIA Security+ (SY0-601) Course Notes," [professormesser.com](https://web.archive.org/web/20220521181010/https://www.professormesser.com/security-plus/sy0-601/sy0-601-video/sy0-601-comptia-security-plus-course/), September 2021.

# %% [markdown]
# ***
# ## END

# %% [markdown]
# < [Table of Contents](#top) | [References](#references) >
# <a id="appendix"></a>
# ***
# ## Appendix
# ***

# %% [markdown]
# ***
# ## END

# %%
from IPython.core.display import display,HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# C:\Users\SeanOhAileasa\AppData\Local\Temp\ipykernel_1364\1322614208.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display,HTML
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # END JUPYTER NOTEBOOK
